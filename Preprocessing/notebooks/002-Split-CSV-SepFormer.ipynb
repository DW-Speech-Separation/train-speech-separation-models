# %%
import pandas as pd

# %%
ROOT_CSV  ="/content/drive/Shareddrives/TG-Separación-Fuentes/code/"
PATH_SEPFORMER_CSV_TEST = ROOT_CSV+"SEPFORMER_mixture_train_mix_clean_callfriend_spanish.csv"

# %%
df_test = pd.read_csv(PATH_SEPFORMER_CSV_TEST)

# %%
start = 62636
end = 68000

pos = "_"+str(start)+"_"+str(end)+".csv"

df_test.iloc[start:end].to_csv(PATH_SEPFORMER_CSV_TEST.replace(".csv",pos))

# %%
df_test.shape
# Out:
# (87441, 14)
